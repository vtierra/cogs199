# %%
import pandas as pd
import string as st
import math
import matplotlib
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#Read csv file
data= pd.read_csv("vince_5_dsi7_filtered_noheader.csv")

# %%
#plot the raw data form the csv

plt.xlabel('Time')
plt.ylabel('Voltage')
df1_voltage = data[['E1', 'E2','E3','E4','E5','E6','E7']]
plt.plot(range(len(df1_voltage)), df1_voltage)
plt.legend(('E1', 'E2', 'E3', 'E4', 'E5', 'E6','E7'),bbox_to_anchor=(1.15,1), borderaxespad=0)

# %%
plt.plot(range(len(df1_voltage)), df1_voltage['E1'])
plt.legend(('E1'),bbox_to_anchor=(1.15,1), borderaxespad=0)

# %%
#Take the average of the sample (I think Q headset is 300hz/sec) double check

E1_avg=[]
E2_avg=[]
E3_avg=[]
E4_avg=[]
E5_avg=[]
E6_avg=[]
E7_avg=[]
i=0;
while i < len(data['E1']):
    E1_avg.append(np.sum(data['E1'][i:300+i])/300);
    E2_avg.append(np.sum(data['E2'][i:300+i])/300);
    E3_avg.append(np.sum(data['E3'][i:300+i])/300);
    E4_avg.append(np.sum(data['E4'][i:300+i])/300);
    E5_avg.append(np.sum(data['E5'][i:300+i])/300);
    E6_avg.append(np.sum(data['E6'][i:300+i])/300);
    E7_avg.append(np.sum(data['E7'][i:300+i])/300);
    i = i+300;

# %%
#Create a new dataframe with the average values

avg_df = pd.DataFrame([E1_avg, E2_avg, E3_avg, E4_avg, E5_avg, E6_avg, E7_avg])
avg_df = avg_df.transpose()
avg_df.rename(columns={0:"E1", 1:"E2", 2:"E3", 3:"E4", 4:"E5", 5:"E6", 6:"E7"}, inplace=True)

# %%
#Visualize the filtered/averaged dataset

plt.xlabel('Time')
plt.ylabel('Voltage')
avg_df = avg_df[['E1', 'E2','E3','E4','E5','E6', 'E7']]
plt.plot(range(len(avg_df)), avg_df)
plt.legend(('E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7'),bbox_to_anchor=(1.15,1), borderaxespad=0)

# %%
plt.plot(range(len(avg_df)), avg_df['E1'])
plt.legend(('E1'),bbox_to_anchor=(1.15,1), borderaxespad=0)

# %%
plt.plot(range(len(avg_df)), avg_df['E2'])
plt.legend(('E2'),bbox_to_anchor=(1.15,1), borderaxespad=0)

# %%
plt.plot(range(len(avg_df)), avg_df['E3'])
plt.legend(('E1'),bbox_to_anchor=(1.15,1), borderaxespad=0)

# %%
plt.plot(range(len(avg_df)), avg_df['E4'])
plt.legend(('E1'),bbox_to_anchor=(1.15,1), borderaxespad=0)

# %%
plt.plot(range(len(avg_df)), avg_df['E5'])
plt.legend(('E1'),bbox_to_anchor=(1.15,1), borderaxespad=0)

# %%
plt.plot(range(len(avg_df)), avg_df['E6'])
plt.legend(('E1'),bbox_to_anchor=(1.15,1), borderaxespad=0)

# %% [raw]
# plt.plot(range(len(avg_df)), avg_df['E7'])
# plt.legend(('E1'),bbox_to_anchor=(1.15,1), borderaxespad=0)
